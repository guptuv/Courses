# %%
# %pip install numpy matplotlib seaborn pandas
# !pip install seaborn numpy matplotlib pandas

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
# Out:
# [notice] A new release of pip is available: 23.2.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...

# %%
df=pd.read_csv('placement_data.csv')

# %%
df.head()
# Out:
#    cgpa  resume_score  placed
# 0  3.75          1.85       0
# 1  9.51          5.42       0
# 2  7.32          8.73       1
# 3  5.99          7.32       0
# 4  1.56          8.07       0

# %%
df.shape
# Out:
# (1000, 3)

# %%
sns.scatterplot(data=df, x='cgpa', y='resume_score', hue='placed')
# Out:
# <Axes: xlabel='cgpa', ylabel='resume_score'>

# %%
sns.scatterplot(data=df, y='cgpa', x='resume_score', hue='placed')
# Out:
# <Axes: xlabel='resume_score', ylabel='cgpa'>

# %%
X = df[['cgpa', 'resume_score']]   
y = df['placed']

# %%
# !pip install scikit-learn

from sklearn.linear_model import Perceptron
p = Perceptron()
# Out:
# ...
# [notice] A new release of pip is available: 23.2.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
p.fit(X,y)
# Out:
# Perceptron()

# %%
p.coef_
# Out:
# array([[10.25,  8.52]])

# %%
# !pip install mlxtend
from mlxtend.plotting import plot_decision_regions
# Out:
# ...
# [notice] A new release of pip is available: 23.2.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
plot_decision_regions(X.values, y.values, clf=p, legend=1)
# Out:
# d:\Programming\Courses\Deep Learning\dl\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but Perceptron was fitted with feature names
#   warnings.warn(
# <Axes: >
