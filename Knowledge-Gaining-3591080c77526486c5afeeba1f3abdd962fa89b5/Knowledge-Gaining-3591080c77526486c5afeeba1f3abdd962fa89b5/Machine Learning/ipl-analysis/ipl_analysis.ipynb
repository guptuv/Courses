# %%
import numpy as np
import pandas as pd

# %%
data=pd.read_csv('/content/matches - matches.csv')
data
# Out:
#       id  season       city        date                        team1  \
# 0      1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1      2    2017       Pune  2017-04-06               Mumbai Indians
# 2      3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3      4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4      5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# ..   ...     ...        ...         ...                          ...
# 631  632    2016     Raipur  2016-05-22             Delhi Daredevils
# 632  633    2016  Bangalore  2016-05-24                Gujarat Lions
# 633  634    2016      Delhi  2016-05-25          Sunrisers Hyderabad
# 634  635    2016      Delhi  2016-05-27                Gujarat Lions
# 635  636    2016  Bangalore  2016-05-29          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
data.tail()
# Out:
#       id  season       city        date                team1  \
# 631  632    2016     Raipur  2016-05-22     Delhi Daredevils
# 632  633    2016  Bangalore  2016-05-24        Gujarat Lions
# 633  634    2016      Delhi  2016-05-25  Sunrisers Hyderabad
# 634  635    2016      Delhi  2016-05-27        Gujarat Lions
# 635  636    2016  Bangalore  2016-05-29  Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# 631  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 632  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 633        Kolkata Knight Riders        Kolkata Knight Riders         field
# 634          Sunrisers Hyderabad          Sunrisers Hyderabad         field
# 635  Royal Challengers Bangalore          Sunrisers Hyderabad           bat
#
#      result  dl_applied                       winner  win_by_runs  \
# 631  normal           0  Royal Challengers Bangalore            0
# ...

# %%
data.shape
# Out:
# (636, 18)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 636 entries, 0 to 635
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               636 non-null    int64
#  1   season           636 non-null    int64
#  2   city             629 non-null    object
#  3   date             636 non-null    object
#  4   team1            636 non-null    object
#  5   team2            636 non-null    object
#  6   toss_winner      636 non-null    object
#  7   toss_decision    636 non-null    object
#  8   result           636 non-null    object
#  9   dl_applied       636 non-null    int64
#  10  winner           633 non-null    object
#  11  win_by_runs      636 non-null    int64
#  12  win_by_wickets   636 non-null    int64
#  13  player_of_match  633 non-null    object
#  14  venue            636 non-null    object
#  15  umpire1          635 non-null    object
#  16  umpire2          635 non-null    object
# ...

# %%
data.describe()
# Out:
#                id       season  dl_applied  win_by_runs  win_by_wickets  \
# count  636.000000   636.000000  636.000000   636.000000      636.000000
# mean   318.500000  2012.490566    0.025157    13.682390        3.372642
# std    183.741666     2.773026    0.156726    23.908877        3.420338
# min      1.000000  2008.000000    0.000000     0.000000        0.000000
# 25%    159.750000  2010.000000    0.000000     0.000000        0.000000
# 50%    318.500000  2012.000000    0.000000     0.000000        4.000000
# 75%    477.250000  2015.000000    0.000000    20.000000        7.000000
# max    636.000000  2017.000000    1.000000   146.000000       10.000000
#
#        umpire3
# count      0.0
# mean       NaN
# std        NaN
# min        NaN
# 25%        NaN
# 50%        NaN
# 75%        NaN
# max        NaN

# %%
data['winner']
# Out:
# 0              Sunrisers Hyderabad
# 1           Rising Pune Supergiant
# 2            Kolkata Knight Riders
# 3                  Kings XI Punjab
# 4      Royal Challengers Bangalore
#                   ...
# 631    Royal Challengers Bangalore
# 632    Royal Challengers Bangalore
# 633            Sunrisers Hyderabad
# 634            Sunrisers Hyderabad
# 635            Sunrisers Hyderabad
# Name: winner, Length: 636, dtype: object

# %%
data[['team1','team2','winner']]
# Out:
#                            team1                        team2  \
# 0            Sunrisers Hyderabad  Royal Challengers Bangalore
# 1                 Mumbai Indians       Rising Pune Supergiant
# 2                  Gujarat Lions        Kolkata Knight Riders
# 3         Rising Pune Supergiant              Kings XI Punjab
# 4    Royal Challengers Bangalore             Delhi Daredevils
# ..                           ...                          ...
# 631             Delhi Daredevils  Royal Challengers Bangalore
# 632                Gujarat Lions  Royal Challengers Bangalore
# 633          Sunrisers Hyderabad        Kolkata Knight Riders
# 634                Gujarat Lions          Sunrisers Hyderabad
# 635          Sunrisers Hyderabad  Royal Challengers Bangalore
#
#                           winner
# 0            Sunrisers Hyderabad
# 1         Rising Pune Supergiant
# 2          Kolkata Knight Riders
# 3                Kings XI Punjab
# 4    Royal Challengers Bangalore
# ...

# %%
data.iloc[[56,98]]
# Out:
#     id  season       city        date                  team1  \
# 56  57    2017  Bangalore  2017-05-17    Sunrisers Hyderabad
# 98  99    2008     Mumbai  2008-05-16  Kolkata Knight Riders
#
#                     team2            toss_winner toss_decision  result  \
# 56  Kolkata Knight Riders  Kolkata Knight Riders         field  normal
# 98         Mumbai Indians         Mumbai Indians         field  normal
#
#     dl_applied                 winner  win_by_runs  win_by_wickets  \
# 56           1  Kolkata Knight Riders            0               7
# 98           0         Mumbai Indians            0               8
#
#     player_of_match                  venue       umpire1      umpire2  umpire3
# 56  NM Coulter-Nile  M Chinnaswamy Stadium  AK Chaudhary  Nitin Menon      NaN
# 98       SM Pollock       Wankhede Stadium   BR Doctrove    DJ Harper      NaN

# %%
type(data.iloc[1:3])
# Out:
# pandas.core.frame.DataFrame

# %%
#fancy indexing
data.iloc[[5,6,3]]
# Out:
#    id  season       city        date                   team1  \
# 5   6    2017  Hyderabad  2017-04-09           Gujarat Lions
# 6   7    2017     Mumbai  2017-04-09   Kolkata Knight Riders
# 3   4    2017     Indore  2017-04-08  Rising Pune Supergiant
#
#                  team2          toss_winner toss_decision  result  dl_applied  \
# 5  Sunrisers Hyderabad  Sunrisers Hyderabad         field  normal           0
# 6       Mumbai Indians       Mumbai Indians         field  normal           0
# 3      Kings XI Punjab      Kings XI Punjab         field  normal           0
#
#                 winner  win_by_runs  win_by_wickets player_of_match  \
# 5  Sunrisers Hyderabad            0               9     Rashid Khan
# 6       Mumbai Indians            0               4          N Rana
# 3      Kings XI Punjab            0               6      GJ Maxwell
#
#                                        venue       umpire1        umpire2  \
# ...

# %%
data.iloc[:,[4,5,2]]
# Out:
#                            team1                        team2       city
# 0            Sunrisers Hyderabad  Royal Challengers Bangalore  Hyderabad
# 1                 Mumbai Indians       Rising Pune Supergiant       Pune
# 2                  Gujarat Lions        Kolkata Knight Riders     Rajkot
# 3         Rising Pune Supergiant              Kings XI Punjab     Indore
# 4    Royal Challengers Bangalore             Delhi Daredevils  Bangalore
# ..                           ...                          ...        ...
# 631             Delhi Daredevils  Royal Challengers Bangalore     Raipur
# 632                Gujarat Lions  Royal Challengers Bangalore  Bangalore
# 633          Sunrisers Hyderabad        Kolkata Knight Riders      Delhi
# 634                Gujarat Lions          Sunrisers Hyderabad      Delhi
# 635          Sunrisers Hyderabad  Royal Challengers Bangalore  Bangalore
#
# [636 rows x 3 columns]

# %%
mask=data['city']=='Hyderabad'
mask
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 631    False
# 632    False
# 633    False
# 634    False
# 635    False
# Name: city, Length: 636, dtype: bool

# %%
data[mask].shape[0]
# Out:
# 49

# %%
def get_city(city):
  mask=data['city']==city
  return data[mask].shape[0]

# %%
get_city('Bangalore')
# get_city('Hyderabad')
# get_city('Delhi')
# get_city('Mumbai')
# get_city('Rajkot')
# Out:
# 66

# %%
m1=data['city']=='Hyderabad'
m2=data['date']>='2010-01-01'

# %%
data[m1&m2].shape[0]
# Out:
# 42

# %%
data['city'].value_counts()
# Out:
# city
# Mumbai            85
# Bangalore         66
# Kolkata           61
# Delhi             60
# Hyderabad         49
# Chennai           48
# Chandigarh        46
# Jaipur            33
# Pune              32
# Durban            15
# Centurion         12
# Ahmedabad         12
# Visakhapatnam     11
# Rajkot            10
# Dharamsala         9
# Johannesburg       8
# Cape Town          7
# Port Elizabeth     7
# Ranchi             7
# Abu Dhabi          7
# Cuttack            7
# Raipur             6
# Sharjah            6
# Indore             5
# Kochi              5
# Kanpur             4
# East London        3
# Kimberley          3
# Nagpur             3
# Bloemfontein       2
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
data['city'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='city'>

# %%
data['city'].value_counts().plot(kind='barh')
# Out:
# <Axes: ylabel='city'>

# %%
data['city'].value_counts().head().plot(kind='bar')
# Out:
# <Axes: xlabel='city'>

# %%
# data['toss_decision'].value_counts().plot(kind='pie')
data['toss_decision'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
data['win_by_runs'].plot(kind='hist')
type(data['win_by_runs'])
# Out:
# pandas.core.series.Series

# %%
print(1,data['winner'].shape,end="\n-------\n")
print(2,data['winner'].value_counts().shape,end="\n-------\n")
print(3,type(data['winner']))
print(4,type(data['winner'].value_counts()))
print(5,type(data['winner'].value_counts().plot(kind='barh')))
print(6,data['winner'])
# Out:
# 1 (636,)
# -------
# 2 (14,)
# -------
# 3 <class 'pandas.core.series.Series'>
# 4 <class 'pandas.core.series.Series'>
# 5 <class 'matplotlib.axes._axes.Axes'>
# 6 0              Sunrisers Hyderabad
# 1           Rising Pune Supergiant
# 2            Kolkata Knight Riders
# 3                  Kings XI Punjab
# 4      Royal Challengers Bangalore
#                   ...
# 631    Royal Challengers Bangalore
# 632    Royal Challengers Bangalore
# 633            Sunrisers Hyderabad
# 634            Sunrisers Hyderabad
# 635            Sunrisers Hyderabad
# Name: winner, Length: 636, dtype: object

# %%
(data['team1'].value_counts()+data['team2'].value_counts()).shape
# Out:
# (14,)

# %%
def mean(x):
  print(x.shape)
  return(sum(x)/x.shape[0])

# %%
x=mean(data['team1'].value_counts()+data['team2'].value_counts())
x
# Out:
# (14,)
# 90.85714285714286

# %%
(data['team1'].value_counts()+data['team2'].value_counts()).sort_values(ascending=False)
# Out:
# Mumbai Indians                 157
# Royal Challengers Bangalore    152
# Kings XI Punjab                148
# Kolkata Knight Riders          148
# Delhi Daredevils               147
# Chennai Super Kings            131
# Rajasthan Royals               118
# Sunrisers Hyderabad             76
# Deccan Chargers                 75
# Pune Warriors                   46
# Gujarat Lions                   30
# Rising Pune Supergiant          16
# Kochi Tuskers Kerala            14
# Rising Pune Supergiants         14
# Name: count, dtype: int64

# %%
x==(data['team1'].value_counts()+data['team2'].value_counts()).describe()['mean']
# Out:
# np.True_

# %% [markdown]
# yayay!!

# %%
data
# Out:
#       id  season       city        date                        team1  \
# 0      1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1      2    2017       Pune  2017-04-06               Mumbai Indians
# 2      3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3      4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4      5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# ..   ...     ...        ...         ...                          ...
# 631  632    2016     Raipur  2016-05-22             Delhi Daredevils
# 632  633    2016  Bangalore  2016-05-24                Gujarat Lions
# 633  634    2016      Delhi  2016-05-25          Sunrisers Hyderabad
# 634  635    2016      Delhi  2016-05-27                Gujarat Lions
# 635  636    2016  Bangalore  2016-05-29          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
data.drop_duplicates(subset=['city','season'])
# Out:
#       id  season           city        date                        team1  \
# 0      1    2017      Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1      2    2017           Pune  2017-04-06               Mumbai Indians
# 2      3    2017         Rajkot  2017-04-07                Gujarat Lions
# 3      4    2017         Indore  2017-04-08       Rising Pune Supergiant
# 4      5    2017      Bangalore  2017-04-08  Royal Challengers Bangalore
# ..   ...     ...            ...         ...                          ...
# 583  584    2016      Hyderabad  2016-04-16          Sunrisers Hyderabad
# 591  592    2016           Pune  2016-04-22  Royal Challengers Bangalore
# 612  613    2016  Visakhapatnam  2016-05-08          Sunrisers Hyderabad
# 626  627    2016         Kanpur  2016-05-19        Kolkata Knight Riders
# 627  628    2016         Raipur  2016-05-20          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...
