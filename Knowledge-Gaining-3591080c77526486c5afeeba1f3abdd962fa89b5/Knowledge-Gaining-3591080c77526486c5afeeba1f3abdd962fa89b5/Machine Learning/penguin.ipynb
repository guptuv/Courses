# %%
import seaborn as sns

# %%
from pandas.core.frame import DataFrame
df=sns.load_dataset("penguins")
df
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
sns.relplot(
    df,
    x="bill_length_mm", y="bill_depth_mm", hue="body_mass_g", row='island'
)

# %%
df
# Out:
# island          Biscoe        Dream    Torgersen
# species
# Adelie     3709.659091  3688.392857  3706.372549
# Chinstrap          NaN  3733.088235          NaN
# Gentoo     5076.016260          NaN          NaN

# %%
sns.displot(df, kind="kde",x="bill_length_mm", y="bill_depth_mm",col="island",color="pink")

# %%
df
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
x=df.describe()
sns.heatmap(x)
# Out:
# <Axes: xlabel='island'>

# %%
df=df.pivot_table(index="species", columns="island", values="body_mass_g")
df
# Out:
# island          Biscoe        Dream    Torgersen
# species
# Adelie     3709.659091  3688.392857  3706.372549
# Chinstrap          NaN  3733.088235          NaN
# Gentoo     5076.016260          NaN          NaN

# %%
df
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
sns.clustermap(df.iloc[:, [2,3,4,5]].dropna(),cmap="winter")

# %%
sns.heatmap(df,cmap="summer",annot=True)
# Out:
# <Axes: xlabel='island', ylabel='species'>

# %%
sns.heatmap(df,cmap="viridis",annot=True)
# Out:
# <Axes: xlabel='island', ylabel='species'>
